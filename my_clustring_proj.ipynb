# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from my_clustring import KMeans
from sklearn.cluster import AgglomerativeClustering
from scipy.cluster.hierarchy import dendrogram, linkage
from scipy.spatial.distance import pdist

# %%
data = pd.read_csv("data.csv")
data
# Out:
#      feature1  feature2  label
# 0   -0.554244 -9.069390      0
# 1    5.349325 -4.032421      1
# 2   -0.886183 -4.567806      2
# 3   -0.452980 -4.207660      2
# 4    7.394874 -4.501492      1
# ..        ...       ...    ...
# 495 -1.009610 -9.653775      0
# 496 -2.579749 -8.521950      0
# 497  6.966737 -5.674418      1
# 498 -1.751356 -4.616674      2
# 499 -1.257978 -8.007435      0
#
# [500 rows x 3 columns]

# %%
x = data.drop("label", axis=1)
y = data["label"]

# %%
plt.scatter(x["feature1"], x["feature2"])
plt.show()

# %%
k = KMeans(n_clusters=3)
k.fit(x.values)

# %%
k.labels
# Out:
# [[2,
#   3,
#   12,
#   15,
#   19,
#   29,
#   33,
#   34,
#   37,
#   44,
#   45,
#   46,
#   47,
#   50,
#   51,
#   53,
#   54,
#   56,
#   58,
#   61,
#   64,
#   69,
#   70,
#   73,
#   79,
#   81,
#   82,
#   84,
#   87,
#   88,
#   94,
#   96,
#   98,
#   100,
#   102,
#   109,
#   110,
#   111,
#   120,
#   121,
#   123,
#   126,
#   131,
#   132,
#   133,
#   137,
#   141,
#   155,
#   156,
#   157,
#   159,
#   160,
#   162,
#   163,
#   166,
#   167,
#   171,
#   173,
#   174,
#   175,
#   176,
#   177,
#   178,
#   181,
#   186,
#   190,
#   191,
#   194,
#   195,
#   197,
#   198,
#   201,
#   208,
#   214,
#   217,
#   220,
#   222,
#   223,
#   224,
#   227,
#   228,
#   230,
#   234,
#   235,
#   240,
#   241,
#   245,
#   246,
#   249,
#   251,
#   254,
#   255,
#   257,
#   266,
#   267,
#   273,
#   275,
#   277,
#   279,
#   283,
#   284,
#   285,
#   289,
#   290,
#   297,
#   300,
#   301,
#   303,
#   307,
#   315,
#   316,
#   327,
#   331,
#   332,
#   336,
# ...

# %%
predicted_cluster = k.predict(x.values)
plt.scatter(x["feature1"], x["feature2"], c=predicted_cluster)

# %%
for i, idx in enumerate(k.labels):
    point = x.values[idx].T
    plt.scatter(*point)

for i in k.centroids:
    plt.scatter(*i, marker="x", c="black")

# %%
from sklearn.cluster import KMeans

# %%
model = KMeans(n_clusters=3, init="k-means++", tol=1e4)
model.fit(x)
# Out:
# c:\Users\Abd-el-Rahman\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Abd-el-Rahman\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# KMeans(n_clusters=3, tol=10000.0)

# %%
predicted_cluster = model.predict(x)
plt.scatter(x["feature1"], x["feature2"], c=predicted_cluster)
plt.scatter(model.cluster_centers_[:,0], model.cluster_centers_[:,1], c="red", marker="x")

# %%
model.cluster_centers_
# Out:
# array([[ 5.85711934, -4.18282403],
#        [-0.87920127, -3.87203259],
#        [-1.86315371, -8.87400825]])

# %%
max_clusres = 10
distances = []
for i in range(1, max_clusres+1):
    model = KMeans(n_clusters=i)
    model.fit(x)
    distances.append(model.inertia_)
plt.plot(range(1, max_clusres+1), distances, marker="o")
# Out:
# c:\Users\Abd-el-Rahman\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# c:\Users\Abd-el-Rahman\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:1382: UserWarning: KMeans is known to have a memory leak on Windows with MKL, when there are less chunks than available threads. You can avoid it by setting the environment variable OMP_NUM_THREADS=2.
#   warnings.warn(
# c:\Users\Abd-el-Rahman\anaconda3\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# ...

# %%
model = AgglomerativeClustering(n_clusters=3)
model.fit(x)
# Out:
# AgglomerativeClustering(n_clusters=3)

# %%
plt.scatter(x["feature1"], x["feature2"], c=model.labels_)

# %%
distances = pdist(x)
z = linkage(distances, method="ward")
dendrogram(z)
# Out:
# {'icoord': [[5.0, 5.0, 15.0, 15.0],
#   [35.0, 35.0, 45.0, 45.0],
#   [25.0, 25.0, 40.0, 40.0],
#   [10.0, 10.0, 32.5, 32.5],
#   [65.0, 65.0, 75.0, 75.0],
#   [55.0, 55.0, 70.0, 70.0],
#   [21.25, 21.25, 62.5, 62.5],
#   [95.0, 95.0, 105.0, 105.0],
#   [85.0, 85.0, 100.0, 100.0],
#   [125.0, 125.0, 135.0, 135.0],
#   [115.0, 115.0, 130.0, 130.0],
#   [92.5, 92.5, 122.5, 122.5],
#   [41.875, 41.875, 107.5, 107.5],
#   [145.0, 145.0, 155.0, 155.0],
#   [175.0, 175.0, 185.0, 185.0],
#   [165.0, 165.0, 180.0, 180.0],
#   [150.0, 150.0, 172.5, 172.5],
#   [205.0, 205.0, 215.0, 215.0],
#   [195.0, 195.0, 210.0, 210.0],
#   [225.0, 225.0, 235.0, 235.0],
#   [202.5, 202.5, 230.0, 230.0],
#   [255.0, 255.0, 265.0, 265.0],
#   [245.0, 245.0, 260.0, 260.0],
#   [285.0, 285.0, 295.0, 295.0],
#   [275.0, 275.0, 290.0, 290.0],
#   [252.5, 252.5, 282.5, 282.5],
#   [216.25, 216.25, 267.5, 267.5],
#   [161.25, 161.25, 241.875, 241.875],
#   [305.0, 305.0, 315.0, 315.0],
# ...
